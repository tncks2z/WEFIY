# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time
from datetime import datetime
import re

# %%
genre = ['drama', 'crime', 'comedy', 'thriller', 'action', 'romance', 'fantasy']

drama_url = ['https://www.imdb.com/title/tt15553922/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt10919420/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt14819828/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt14169960/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt8769260/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt17513352/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt5679572/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt6611916/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt12235718/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt11612120/reviews?ref_=tt_urv']

crime_url = ['https://www.imdb.com/title/tt15553922/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt12235718/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt6461346/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt5332206/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt6263222/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt13885336/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt13433812/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt12940504/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt8801670/reviews?ref_=tt_urv',
            'https://www.imdb.com/title/tt6212854/reviews?ref_=tt_urv']

comedy_url = ['https://www.imdb.com/title/tt14819828/reviews?ref_=tt_urv',
             'https://www.imdb.com/title/tt8769260/reviews?ref_=tt_urv',
             'https://www.imdb.com/title/tt5679572/reviews?ref_=tt_urv',
             'https://www.imdb.com/title/tt12451520/reviews?ref_=tt_urv',
             'https://www.imdb.com/title/tt15026724/reviews?ref_=tt_urv',
             'https://www.imdb.com/title/tt11769304/reviews?ref_=tt_urv',
             'https://www.imdb.com/title/tt10559276/reviews?ref_=tt_urv',
             'https://www.imdb.com/title/tt9466968/reviews?ref_=tt_urv',
             'https://www.imdb.com/title/tt14518756/reviews?ref_=tt_urv',
             'https://www.imdb.com/title/tt6263222/reviews?ref_=tt_urv']

thriller_url = ['https://www.imdb.com/title/tt10919420/reviews?ref_=tt_urv',
               'https://www.imdb.com/title/tt14169960/reviews?ref_=tt_urv',
               'https://www.imdb.com/title/tt6611916/reviews?ref_=tt_urv',
               'https://www.imdb.com/title/tt12235718/reviews?ref_=tt_urv',
               'https://www.imdb.com/title/tt6461346/reviews?ref_=tt_urv',
               'https://www.imdb.com/title/tt5332206/reviews?ref_=tt_urv',
               'https://www.imdb.com/title/tt13634872/reviews?ref_=tt_urv',
               'https://www.imdb.com/title/tt8199972/reviews?ref_=tt_urv',
               'https://www.imdb.com/title/tt12940504/reviews?ref_=tt_urv',
               'https://www.imdb.com/title/tt11570202/reviews?ref_=tt_urv']

action_url = ['https://www.imdb.com/title/tt10919420/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt14169960/reviews?ref_=tt_urv',
             'https://www.imdb.com/title/tt6611916/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt7094780/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt6263222/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt13433812/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt12940504/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt8236556/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt5320412/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt8523042/reviews?ref_=tt_urv']

romance_url = ['https://www.imdb.com/title/tt8769260/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt17513352/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt5679572/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt12451520/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt11239552/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt7094780/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt15181094/reviews?ref_=tt_urv',
               'https://www.imdb.com/title/tt10192576/reviews?ref_=tt_urv',
               'https://www.imdb.com/title/tt10559276/reviews?ref_=tt_urv',
               'https://www.imdb.com/title/tt9466968/reviews?ref_=tt_urv']

fantasy_url = ['https://www.imdb.com/title/tt14169960/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt5679572/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt6611916/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt12235718/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt11612120/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt5332206/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt13273826/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt9466968/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt6263222/reviews?ref_=tt_urv',
              'https://www.imdb.com/title/tt8801708/reviews?ref_=tt_urv']

WHOLE_URL = [drama_url, crime_url, comedy_url, thriller_url, action_url, romance_url, fantasy_url]
review_dic = {'genre': [], 'review': []}

# %%
driver = webdriver.Chrome('/opt/homebrew/Caskroom/chromedriver/99.0.4844.51/chromedriver')
driver.set_page_load_timeout("20")

# 작품 구분없이 장르별 드라마 10개의 리뷰 가져오기
for i in range(3):
    for j in range(10):
        url = WHOLE_URL[i + 4][j]
        time.sleep(5)
        driver.get(url)
        
        # 작품 제목
#         title = driver.find_element_by_css_selector('#main > section > div.subpage_title_block > div > div > h3 > a').text
#         print("title", title)
        
        # 댓글 수
        review_counts = driver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/section/div[2]/div[1]/div/span').text
        review_counts = int(review_counts.split(' ')[0].replace(',', ''))
        
        # Load More 끝날 때까지 반복
        for k in range(review_counts):    
            try:
                driver.find_element_by_class_name("ipl-load-more__button").send_keys(Keys.ENTER)
                time.sleep(3)
            except Exception as ex:
                print('더이상 "Load More" 없음', ex)
                break

        # 댓글 수집
        print(" 댓글 수집 ")
        try:
            time.sleep(0.5)
            soup= BeautifulSoup(driver.page_source)
            time.sleep(1)

            comment=[]
            x= soup.find_all("div", class_="content")

            for h in x:
                try:
                    tmp= h.find_all("div", class_="text show-more__control")[0].text
                    review_dic['genre'].append(genre[i + 4])
                    review_dic['review'].append(tmp)
                    
                except Exception as ex:
                    tmp= h.find_all("div", class_="text show-more__control clickable")[0].text
                    review_dic['genre'].append(genre[i + 4])
                    review_dic['review'].append(tmp)

            time.sleep(1)
        except Exception as ex:
            re=['nothing']
            print("댓글없음")

        # 한줄평
        print("한줄평 수집 ")
        try:
            oneline=[]
            x= soup.find_all("div", class_="lister-item-content")
            for h in x:
                ol= h.find_all("a", class_="title")[0].text
                review_dic['genre'].append(genre[i + 4])
                review_dic['review'].append(ol)
                
            time.sleep(0.5)

        except Exception as ex:
            oneline= 'nothing'
            print("")

        time.sleep(1)
        print(datetime.now())
        print("---수집 댓글, 한줄평 저장---")
# Out:
# /var/folders/tz/2xhtx7px4kng48d7grkk8mwm0000gn/T/ipykernel_8900/739304638.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/opt/homebrew/Caskroom/chromedriver/99.0.4844.51/chromedriver')
# /var/folders/tz/2xhtx7px4kng48d7grkk8mwm0000gn/T/ipykernel_8900/739304638.py:16: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   review_counts = driver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[3]/div[1]/section/div[2]/div[1]/div/span').text
# /var/folders/tz/2xhtx7px4kng48d7grkk8mwm0000gn/T/ipykernel_8900/739304638.py:22: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   driver.find_element_by_class_name("ipl-load-more__button").send_keys(Keys.ENTER)
# 더이상 "Load More" 없음 Message: element not interactable
#   (Session info: chrome=99.0.4844.84)
# Stacktrace:
# ...

# %%
import pandas as pd
df_review = pd.DataFrame(review_dic)
df_review
# Out:
#          genre                                             review
# 0        drama  The series is about the cases of a judge in a ...
# 1        drama  It is such laziness that raises the counter ar...
# 2        drama  Ignore the paid-for, planted raves in the revi...
# 3        drama  I found this series to be very touching, bring...
# 4        drama  This is a serious drama that seeks to look car...
# ...        ...                                                ...
# 38079  fantasy               Unique concept but not good enough\n
# 38080  fantasy                                 A Witty Romance!\n
# 38081  fantasy                             The best series ever\n
# 38082  fantasy                                          In love\n
# 38083  fantasy                            What a waste of time!\n
#
# [38084 rows x 2 columns]

# %%
df_review['genre'].nunique()
# Out:
# 7

# %%
df_review.to_csv("imdb_review.csv")

# %%
csv = pd.read_csv('imdb_review.csv')
csv
# Out:
#        Unnamed: 0    genre                                             review
# 0               0    drama  The series is about the cases of a judge in a ...
# 1               1    drama  It is such laziness that raises the counter ar...
# 2               2    drama  Ignore the paid-for, planted raves in the revi...
# 3               3    drama  I found this series to be very touching, bring...
# 4               4    drama  This is a serious drama that seeks to look car...
# ...           ...      ...                                                ...
# 38079       38079  fantasy               Unique concept but not good enough\n
# 38080       38080  fantasy                                 A Witty Romance!\n
# 38081       38081  fantasy                             The best series ever\n
# 38082       38082  fantasy                                          In love\n
# 38083       38083  fantasy                            What a waste of time!\n
#
# [38084 rows x 3 columns]

# %%
csv = csv.drop('Unnamed: 0', axis=1)
csv
# Out:
#          genre                                             review
# 0        drama  The series is about the cases of a judge in a ...
# 1        drama  It is such laziness that raises the counter ar...
# 2        drama  Ignore the paid-for, planted raves in the revi...
# 3        drama  I found this series to be very touching, bring...
# 4        drama  This is a serious drama that seeks to look car...
# ...        ...                                                ...
# 38079  fantasy               Unique concept but not good enough\n
# 38080  fantasy                                 A Witty Romance!\n
# 38081  fantasy                             The best series ever\n
# 38082  fantasy                                          In love\n
# 38083  fantasy                            What a waste of time!\n
#
# [38084 rows x 2 columns]
