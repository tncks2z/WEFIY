# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import spacy
import nltk
import re
import string
import pandas as pd
import numpy as np
import gensim
from gensim import corpora
import matplotlib.pyplot as plt
import json
# %matplotlib inline
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
stop_words = set(stopwords.words('english'))
stop_words.update(('\r\n', '\n\r', 'ever', 'much', 'look', 'squid', 'show', 'thing', "i've", 'anything', 'something', "show's",
                   'www', 'soompi' 'com', 'instagram', 'youtube', 'https', 'mydramalist', 'twitter', 'episode', 'comment', 'scene',
                   'version', "he's", 'gonna', 'series', 'watch', 'everything', 'something', "can't", 'list', 'dramas', 'drama',
                   'wait', 'preview', 'someone', 'everyone', 'dont', 'think', 'season', 'anyone', 'something', 'anything', 'nothing', 'world',
                   'status', 'week', 'name', 'cause', 'time', 'en', 'org', 'wikipedia', 'wiki', 'pbs', 'twimg', 'year', 'point', 'please', 'today',
                   'haha', 'case', 'guess', 'reason', 'person', 'moment', 'sense', 'kinda', 'part', 'movie', 'school', 'start', 'work', 'lead', 'kind',
                   'rate', 'rating', 'rate', 'men', 'example', 'idea', 'half', 'review', 'genre', 'side', "that's", "they're", 'till', 'tell', 'phone',
                   'section', 'number', 'company', 'line', "there's", 'male', 'team', 'rating', 'baby', 'course', 'care', 'cute', 'question', 'help', 'group',
                   'hand', 'spoiler', 'hate', 'need', 'mess', 'change', 'drop', 'date', 'netflix', 'yeah', 'daon', 'park', 'thank', 'lmao', 'damn', "i'll",
                   'kang', 'shinwoo', 'taekyung', 'mean', 'woman', 'hope', 'read', 'fact', 'opinion', 'stuff', 'feel', 'talk', 'song', 'hype',
                   'title', 'type', 'game', 'face', 'country', 'hell', 'film', 'voice', 'night', 'baek', 'hair', 'theory', 'talk', 'wonder', 'body', 'title', 'judge',
                   'wife', 'jung', 'mother', 'love', 'family', 'killer', 'hyun', 'girl', 'brother', 'writer', 'sung', 'joon', 'child', 'husband', 'song',
                   'story', 'character', 'plot', 'romance', 'chemistry', 'role', 'couple', 'actor', 'love', 'development', 'cast', 'action', 'thriller',
                   'life', 'relationship', 'heart', 'death', 'place', 'doctor', 'situation', 'money', 'mind', 'love', 'friend', 'matter', 'happiness',
                   'chance', 'house', 'head', 'play', 'revenge', 'fall', 'father', 'marriage', 'yoon', 'apartment', 'mature', 'sister', 'prosecutor',
                   'secretary', 'glad', 'check', 'childhood', 'yeon', 'power', 'food', 'storyline', 'twist', 'kyung', 'binge', 'enjoy', 'hospital',
                   'cliche', 'share', 'post', 'break', 'okay', 'business', 'personality', 'support', 'shin_woo', 'support', 'move', 'news', 'reaction',
                   'minute', 'trust', 'problem', 'mystery', 'ba_reum', 'crime', 'murder', 'daughter', 'understand', 'brain', 'mouse',
                   'psychopath', 'blood', 'horror', 'truth', 'triangle', 'hour', 'rewatch', 'sorry', "what's", 'music', 'director', 'comedy',
                   'production', 'cinematography', 'actress', 'pain', 'attention', 'performance', 'reality', 'audience', 'society', 'level',
                   'experience', 'focus', 'quality', 'script', 'message', 'justice', 'room', 'doubt', 'theme', 'none', 'difference', 'view',
                   'mood', 'class', 'culture', 'superb', 'future', 'period', 'vibe', 'information', 'partner', 'identity', 'student', 'buliding',
                   'pace', 'imagine', 'perfect', 'sort', 'answer', 'backstory', 'playlist', 'blame', 'explain', 'industry', 'weekend',
                   'goblin', 'progress', 'crisis', 'beautiful', 'root', 'fiction', 'home', 'bareum', 'dongbaek', 'trailer', 'picture',
                   'town', 'community', 'yumi', 'video', 'jang', 'hyung', 'cant', 'lady', 'interview', 'evidence', 'haru', 'match', 'want',
                   'divorce', 'concept', 'style', 'masterpiece', 'cannot', 'emotion', 'adult', 'deserve', 'ship', 'trope', 'feeling',
                   'cringe', 'admit', 'score', 'conclusion', 'spoil', 'precess', "we're", 'word', 'slice', 'note', 'direction', 'kill',
                   'worth', 'figure', 'tomorrow', 'disease', 'piece', 'village', 'majority', 'dialogue', 'everybody', 'entertainment', 'poster',
                   'accident', 'form', 'friendship', 'taste', 'waste', 'suspense', 'surgery', 'growth', 'turn', 'month', 'humanity', 'murderer',
                   'impression', 'water', 'baseball', 'cliffhanger', 'jump', 'cheesy', 'disappoint', 'criticism', 'execution', 'rest',
                   'amount', 'system', 'female', 'surprise', 'step', 'prison', 'premise', 'city', 'memory', 'camera', 'seat', 'comfort',
                   'victim', 'miss', 'page', 'stay', 'staff', 'forget', 'deal', 'decision', 'call', 'office', 'crush', 'right', 'conversation',
                   'fight', 'respect', 'lawyer', 'meet', 'site', 'jae_hoon', 'dark', 'humor', 'stranger', 'heard', 'smile', 'topic', 'confession',
                   'interest', 'screen', 'joker', 'star', 'violence', 'tension', 'choi', 'dream', 'john', 'explanation', 'stop', 'pure',
                   'fault', "let's", 'reply', 'wanna', 'possibility', 'plan', 'door', 'dude', 'history', 'mention', 'issue', 'choice',
                   'background', 'nobody', 'language', 'hoon', 'didnt', 'synopsis', 'hahaha', 'moon', 'career', 'journey', 'release',
                   'ha_neul', 'player', 'badass', 'gong_hyo', 'trauma', 'shot', 'treat', 'viki', 'hwang', 'content', 'energy', 'expression',
                   'fate', 'aspect', 'ground', 'success', 'push', 'proposal', 'mister', 'master', 'popularity', 'self', 'spot', 'ride',
                   'reveal', 'sunshine', 'nature', 'hellbound', 'link', 'track', 'filler', 'television', "would've", 'sweet', "who's",
                   'disappointment', 'tone', 'count', "could've", 'treatment', 'closure', 'religion', 'image', 'watching', 'bring', 'cloy',
                   'article', 'process', 'anybody', 'response', 'praise', 'college', 'cell', 'cool', 'shame', 'shit', 'lack', 'balance', 'skip',
                   'soul', 'loss', 'genius', 'peace', 'struggle', 'virus', 'drug', 'capitalism', 'bong_yi', 'health', 'orruption', 'sooo', 'advice',
                   "it'll", 'brilliant', 'shock', 'hero', 'impact', 'stage', 'seok', 'yesterday', 'hence', 'cross', 'talent', 'jae_wook', 'parent', 'fire',
                   'research', 'ability', 'monster', 'appreciate', 'account', 'gotta', 'book', 'villain', 'project', 'wise', 'train', 'court', 'option',
                   'sang', 'statement', 'sure', 'cure', 'description', 'interaction', 'source', 'meeting', 'hyejin', 'trash', 'prince', 'value', 'detail',
                   'force', 'order', 'tragedy', 'perfection', 'charm', 'edit', 'stand', 'leader', 'effect', 'scenario', 'boyfriend', 'suit', 'alot',
                   'boring', 'somehow', 'sign', 'endgame', 'yong_shik', 'conflict', 'effort', 'gene', 'trouble', 'fear', 'communication', 'bracelet',
                   'ghost', 'appearance', 'continue', 'wook', 'photo', 'government', 'event', 'top_notch', 'president', 'crazy', 'bitch', 'soundtrack',
                   'control', 'edge', 'state', 'recommend', 'regret', 'approach', 'portrayal', 'space', 'catch', 'investigation', 'breath', 'credit',
                   'test', 'party', 'member', 'discussion', 'jail', 'result', 'connection', 'position', 'bond', 'hyuk', 'cult', 'thought', 'pity',
                   'patient', 'search', 'helpful', 'field', 'flashback', 'factor', 'wall', "they'll", 'condition', 'bathroom',
                   'wish', 'anxiety', 'expectation', 'reference', 'compare', 'excuse', 'sound', 'learn', 'ballet', 'road', 'grandma', 'university', 'heedo',
                   'hometown_cha', 'winner', 'emergency', 'beach', 'design', 'insane', 'corruption', 'hurt', 'badminton', 'creepy', 'hunter', 'become',
                   'predator', 'path', 'courage', 'exception', 'professor', 'ponnu', 'budget', 'guilt', 'rule', 'intention', 'agree', 'little_bit',
                   'strength', 'opportunity', 'crap', 'playbook', 'attitude', 'floor', 'flaw', 'yohan', 'protagonist', 'shik', 'hotel', 'aunt', 'finale',
                   'convince', 'thril', 'front', 'representation', 'manage', "people's", 'anger', 'element', 'core', 'taxi', 'sadness', 'hint',
                   'mine', 'transplant', 'cover', 'dislike', 'immature', 'frustration', 'length', 'building', 'light', 'return', "drama's", 'doom',
                   'joke', 'risk', 'hold', 'cameo', 'environment', 'stress', 'pair', 'route', 'dusik', 'area', 'realise', 'sacrifice', 'mark',
                   'goal', 'attack', 'ruin', 'hyang_mi', 'combination', 'award', 'patience', 'manager', 'soooo', 'beat', 'super', 'animation', 'finish',
                   'gold', 'hari', 'laugh', 'japan', 'hello', 'viewer', 'pressure', 'portray', 'se_young', 'repeat', 'random', 'recognition', 'owner',
                   'variety', 'excitement', 'pull', 'motivation', 'mistake', 'perspective', 'hehe', 'morality', 'competition', 'torture', 'screenwriter',
                   'depth', 'great_job', 'relate', 'pick', 'escape', 'gore', 'danger', 'good_job', 'comparison', 'chairman', 'roller_coaster', 'curiosity',
                   'somebody', 'promise', 'band', 'translation', 'heck', 'teacher', 'progression', 'presence', 'manner', 'psycho', 'passion', 'reporter',
                   'department', 'notice', 'coffee', 'epic', 'youth', 'toxic', 'ryul', 'culprit', 'evil', 'incident', 'alice', 'jerk', 'create', 'borderland',
                   'doesnt', 'rain', 'covid', 'knowledge', 'behavior', 'make', 'color', 'funny', 'living', 'join', 'sentence', 'gang', 'fantasy', "he'll",
                   'affection', 'kingdom', 'confidence', 'worry', 'crew', 'subplot', 'market', 'trend', 'spirit', "baek's", 'drag', "we'll", 'info', 'trio',
                   'bland', 'safety', 'concern', 'eugene', 'illness', 'introduction', 'diagnosis', 'reading', 'imagination', 'record', 'scandal', 'dong_mae',
                   'contract', 'kiss', 'existence', 'affair', "here's", 'material', 'paper', 'speak', 'interpretation', 'birth', 'range', 'characterization',
                   'heal', 'gift', 'cipa', 'thrill', 'punch', 'clever', 'advantage', 'bunch', 'coach', 'summer', 'chief', 'seung', 'distance', 'argument', 'plenty',
                   'kdramas', 'police_officer', 'battle', 'rainbow', 'screenplay', 'term', 'complaint', 'suffer', 'redemption', 'depression', 'report', 'chill', 'cable',
                   'fond', 'daniel_lee', 'revelation', 'definition', 'abuse', 'meant', 'survival', 'gosh', 'weird', 'disorder', 'responsibility', 'grow', 'bittersweet',
                   'marry', 'desire', 'wrap', 'earth', 'confusion', 'protect', "they've", 'drunk', 'fine', 'sequel', 'addition', 'offer', 'hahah', 'darker', 'basis',
                   'youtu', 'cry', 'card', 'complain', 'dong', 'favorite', 'frame', 'restaurant', 'format', 'relief', 'pill', 'sake', 'kindness', 'pointless', 'police',
                   'importance', 'intensity', 'nurse', 'cruel', 'extent', 'grandpa', 'behaviour', 'comeback', 'last_two', 'teaser', 'lesson', 'express', 'officer',
                   'realism', 'author', 'influence', 'confess', 'yang', 'contrast', 'wont', 'operation', 'broadcast', 'clue', 'haneul', 'jaehoon', 'attraction', 'bridge',
                   'fuck', 'practice', 'glass', 'meaning', 'debt', 'min_young', 'morning', 'gain', "today's_episode", 'hollywood', 'simple', 'trip', 'contact', 'hole',
                   'church', 'rude', 'penthouse', 'dance', 'recommendation', 'bonus', 'wasnt', 'lover', 'driver', 'fashion', 'flower', 'punishment', 'foodness', 'education',
                   'adaptation', 'study', 'witch', 'mouth', 'rush', 'chae', 'depiction', 'analysis', 'throw', 'context', 'describe', 'absolute', 'cry', 'bloody', 'handsome',
                   'priority', 'management', 'price', 'mediocre', 'appreciation', 'hater', 'button', 'council', 'science', 'setup', 'breakup', 'schedule', 'next_episode',
                   'location', 'resolution', 'motherhood', 'sohee', "ml's", 'security', 'screentime', 'instance', 'plain', 'visit', 'travel', 'letter', 'neighborhood',
                   'nation', 'land', 'structure', 'substance', 'stalker', 'network', 'many_people', 'del_luna', 'reach', 'purpose', 'witness', 'ignore', 'rollercoaster',
                   'river', 'jisung', 'sucker', 'highlight', "y'all", 'timeline', 'yijin', 'extension', 'encounter', 'internet', 'surface', 'coincidence', 'jaewon', 'finger',
                   'pilot', 'epilogue', 'drawn', 'bored_potato', 'havent', 'shift', 'thinking', 'reputation', 'device', 'google', 'whilst', 'access', 'fill', 'headhunter',
                   'last_ep', 'obsession', 'nope', 'felt', 'dang', 'girlfriend', 'medicine', 'generation', 'build', 'challenge', 'clip', 'decade', 'prof', 'weight',
                   'favourite', 'package', 'club', 'past', 'detective', 'shin_min', 'freedom', 'copy', 'sport', 'halfway', 'chaos', 'beom', 'product', 'middle',
                   'dress', 'speech', 'benefit', 'juvenile', 'shin', 'clich', 'cost', 'shop', 'atleast', 'psychology', 'huge_fan', 'hong_joo', 'gender', 'hide',
                   'rock', 'find', 'formula', 'dinner', 'nonsense', 'scenery', 'ryan', 'jong', 'damage', "he'd", "character's", 'dramacool', 'organization',
                   'board', 'complexity', 'bird', 'chan', 'rise', 'priest', 'agency', 'defense', 'satisfaction', 'acceptance', 'fresh_air', 'appeal', 'lee_jong_suk',
                   'hwa_pyung', 'preference', 'last_episode', 'station', 'goodness', 'center', 'therapy', 'flow', 'minority', 'sequence', 'isnt', 'chapter',
                   'maturity', 'kim_seon_ho', 'stupidity', 'makeup', 'store', 'excellent', 'round', "jin's", 'ikjun', 'plotline', 'truck', 'address', 'pleasure',
                   'handle', 'junwan', 'serie', 'resident', 'ji_chang', 'miracle', 'island'))

# %%
df = pd.read_csv('/content/drive/MyDrive/0425_ENG_final_drama_reviews.csv')

# %%
titles = df['title']

# %%
df_lower = df['reviews'].str.lower()

# %%
df_lower = pd.DataFrame(df_lower)

# %%
df_lower['title'] = titles

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = nltk.collocations.BigramCollocationFinder.from_documents([comment.split() for comment in df_lower.reviews])
# Filter only those that occur at least 50 times
finder.apply_freq_filter(50)
bigram_scores = finder.score_ngrams(bigram_measures.pmi)

# %%
bigram_pmi = pd.DataFrame(bigram_scores)
bigram_pmi.columns = ['bigram', 'pmi']
bigram_pmi.sort_values(by='pmi', axis = 0, ascending = False, inplace = True)

# %%
# Filter for bigrams with only noun-type structures
def bigram_filter(bigram):
    tag = nltk.pos_tag(bigram)
    if tag[0][1] not in ['JJ', 'NN'] and tag[1][1] not in ['NN']:
        return False
    if bigram[0] in stop_words or bigram[1] in stop_words:
        return False
    if 'n' in bigram or 't' in bigram:
        return False
    if 'PRON' in bigram:
        return False
    return True

# %%
# Can set pmi threshold to whatever makes sense - eyeball through and select threshold where n-grams stop making sense
# choose top 500 ngrams in this case ranked by PMI that have noun like structures
filtered_bigram = bigram_pmi[bigram_pmi.apply(lambda bigram:\
                                              bigram_filter(bigram['bigram'])\
                                              and bigram.pmi > 3, axis = 1)][:800]

# filtered_trigram = trigram_pmi[trigram_pmi.apply(lambda trigram: \
#                                                  trigram_filter(trigram['trigram'])\
#                                                  and trigram.pmi > 5, axis = 1)][:500]


bigrams = [' '.join(x) for x in filtered_bigram.bigram.values if len(x[0]) > 3 or len(x[1]) > 3]
# trigrams = [' '.join(x) for x in filtered_trigram.trigram.values if len(x[0]) > 3 or len(x[1]) > 3 and len(x[2]) > 3]

# %%
# Concatenate n-grams
def replace_ngram(x):
    # for gram in trigrams:
    #     x = x.replace(gram, '_'.join(gram.split()))
    for gram in bigrams:
        x = x.replace(gram, '_'.join(gram.split()))
    return x

# %%
reviews_w_ngrams = df_lower.copy()

# %%
reviews_w_ngrams.reviews = reviews_w_ngrams.reviews.map(lambda x: replace_ngram(x))

# %%
reviews_w_ngrams = reviews_w_ngrams.reviews.map(lambda x: [word for word in x.split()\
                                                 if word not in stop_words and len(word) > 3])

# %%
def get_wordnet_pos(pos_tag):
    if pos_tag.startswith('V'):
        return 'v'
    elif pos_tag.startswith('N'):
        return 'n'
    elif pos_tag.startswith('J'):
        return 'a'
    elif pos_tag.startswith('R'):
        return 'r'
    else:
        return None

# %%
word_list = reviews_w_ngrams.to_list()

# %%
lemma = WordNetLemmatizer()
word_list_lemma = []
for ls in word_list:
    word_lem = []
    tag_words = nltk.pos_tag(ls)
    pos_words = []
    for word in tag_words:
        if word[1] in ['NN']:  #'VB', 'VBP', 'JJ'
            pos_words.append(word)
    temp_list = []
    for token, pos_tag in pos_words:
        tag = get_wordnet_pos(pos_tag)
        if tag != None:
            temp_list.append((token, get_wordnet_pos(pos_tag)))
    token_final = [lemma.lemmatize(token, pos=tag) for token, tag in temp_list]
    word_list_lemma.append(token_final)

# %%
# Filter for only nouns
def noun_only(x):
    pos_comment = nltk.pos_tag(x)
    filtered = [word[0] for word in pos_comment if word[1] in ['NN']]
    # to filter both noun and verbs
    #filtered = [word[0] for word in pos_comment if word[1] in ['NN','VB', 'VBD', 'VBG', 'VBN', 'VBZ']]
    return filtered

# %%
word_list_lemma = pd.Series(word_list_lemma)

# %%
final_reviews = word_list_lemma.map(noun_only)

# %%
dictionary = corpora.Dictionary(final_reviews)
dictionary.filter_extremes(no_below=20, no_above=0.5)
doc_term_matrix = [dictionary.doc2bow(doc) for doc in final_reviews]

# %%
coherence = []
for k in range(3, 5):
    print('Round: '+str(k))
    Lda = gensim.models.ldamodel.LdaModel
    ldamodel = Lda(doc_term_matrix, num_topics=k, id2word = dictionary, passes=40,\
                   iterations=250, chunksize = 10000, eval_every = None, random_state=None)
    
    cm = gensim.models.coherencemodel.CoherenceModel(model=ldamodel, texts=final_reviews,\
                                                     dictionary=dictionary, coherence='c_v')

# %%
x_val = [x[0] for x in coherence]
y_val = [x[1] for x in coherence]

# %%
plt.plot(x_val,y_val)
plt.scatter(x_val,y_val)
plt.title('Number of Topics vs. Coherence')
plt.xlabel('Number of Topics')
plt.ylabel('Coherence')
plt.xticks(x_val)
plt.show()

# %%
Lda = gensim.models.ldamodel.LdaModel
ldamodel = Lda(doc_term_matrix, num_topics=10, id2word = dictionary, passes=40,\
               iterations=250,  chunksize = 10000, eval_every = 1, random_state=None)

# %%
# To show initial topics
ldamodel.show_topics(10, num_words=20, formatted=False)
# Out:
# [(0,
#   [('gongjin', 0.012769637),
#    ('fluff', 0.008666996),
#    ('king', 0.008639815),
#    ('emphasis', 0.0081192935),
#    ('compassion', 0.0079224175),
#    ('lord', 0.00791711),
#    ('jtbc', 0.007706925),
#    ('movement', 0.007622149),
#    ('autism', 0.0074346405),
#    ('violent', 0.00737775),
#    ('mentality', 0.007350448),
#    ('street', 0.00709877),
#    ('guarantee', 0.0070976974),
#    ('passionate', 0.007095453),
#    ('anime', 0.0070915185),
#    ('sook', 0.007066498),
#    ('antagonist', 0.0070503885),
#    ('suspect', 0.0069580935),
#    ("characters'", 0.006895448),
#    ('base', 0.006799764)]),
#  (1,
#   [('service', 0.018395972),
#    ('vincenzo', 0.011483828),
#    ('phase', 0.008828674),
#    ('tense', 0.008759941),
#    ('cash', 0.00863704),
#    ('raise', 0.008614315),
#    ('wealth', 0.008447396),
#    ('mirror', 0.008190152),
#    ('cancer', 0.008153248),
#    ('remind', 0.008118017),
#    ('awesome', 0.007955797),
#    ('cringey', 0.007534408),
# ...

# %%
from gensim.test.utils import datapath

temp_file = datapath("/content/drive/MyDrive/LDA/lda_model")
ldamodel.save(temp_file)
# Out:
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:496: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:496: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:496: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)

# %%
from gensim.test.utils import datapath
from gensim.models.ldamodel import LdaModel
temp_file = datapath("/content/drive/MyDrive/LDA/lda_model")
lda = LdaModel.load(temp_file)
# Out:
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:496: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:496: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)
# /usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py:496: DeprecationWarning: This function is deprecated.  See https://github.com/RaRe-Technologies/smart_open/blob/develop/MIGRATING_FROM_OLDER_VERSIONS.rst for more information
#   warnings.warn(message, category=DeprecationWarning)

# %%
# %%capture
# !pip install pyldavis

# %%
import pickle
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable

# %%
pyLDAvis.enable_notebook()
topic_data =  pyLDAvis.gensim_models.prepare(ldamodel, doc_term_matrix, dictionary, mds = 'pcoa')
pyLDAvis.display(topic_data)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el601397733880145449208534480"></div>
# <script type="text/javascript">
#
# ...
