# %%
# %matplotlib inline

# %%
#roco
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 20
plt.rcParams['figure.figsize'] = (8,8)

colors = ['#830213','#9A0002','#B30D02','#8B8680','#A9A9A9','#C0C0C0']
ratio = [18.02,5.95,0.39,0.26,75.38]
explode = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05]
labels = ['플롯','연출','캐릭터','캐릭터(설정)','기타']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 2}

plt.pie(ratio, autopct='', startangle=260, 
        counterclock=False, colors=colors, wedgeprops=wedgeprops, 
        shadow = True)
plt.show()

# %%
#drama
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 20
plt.rcParams['figure.figsize'] = (8,8)

colors = ['#830213','#9A0002','#B30D02','#8B8680','#A9A9A9','#C0C0C0']
ratio = [61.94,12.07,11.55,4.75,9.69]
explode = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05]
labels = ['플롯','연출','캐릭터','소재','기타']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 2}

plt.pie(ratio, labels=labels, autopct='', startangle=260, 
        counterclock=False, colors=colors, wedgeprops=wedgeprops, 
        shadow = True)
plt.show()

# %%
#crime
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 20
plt.rcParams['figure.figsize'] = (8,8)

colors = ['#830213','#9A0002','#B30D02','#8B8680','#A9A9A9','#C0C0C0']
ratio = [15.09, 6.86, 6.72, 6.68, 5.11, 59.54]
explode = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05]
labels = ['플롯','배우','배우','연출','소재','기타']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 2}

plt.pie(ratio, labels=labels, autopct='', startangle=260, 
        counterclock=False, colors=colors, wedgeprops=wedgeprops,
       shadow = True)
plt.show()

# %%
# fantasySF
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 20
plt.rcParams['figure.figsize'] = (8,8)

colors = ['#830213','#9A0002','#B30D02','#614042','#8B8680','#A9A9A9','#C0C0C0']
ratio = [22.33,11.42,9.41,2.06,0.98,53.8]
explode = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05]
labels = ['연출','플롯','요소(휴머니즘, 신파)','소재','배우','기타']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 2}

plt.pie(ratio, autopct='', startangle=260, 
        counterclock=False, colors=colors, wedgeprops=wedgeprops, 
        shadow = True,)

plt.show()

# %%
# fantasySF
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 20
plt.rcParams['figure.figsize'] = (8,8)

colors = ['#830213','#9A0002','#B30D02','#614042','#8B8680','#A9A9A9','#C0C0C0']
ratio = [22.33,11.42,9.41,2.06,0.98,53.8]
explode = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05]
labels = ['연출','플롯','요소(휴머니즘, 신파)','소재','배우','기타']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 2}

plt.pie(ratio, labels = labels, autopct='', startangle=260, 
        counterclock=False, colors=colors, wedgeprops=wedgeprops, 
        shadow = True,)

plt.show()

# %%
#thriller
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 20
plt.rcParams['figure.figsize'] = (8,8)

colors = ['#830213','#9A0002','#B30D02','#614042','#8B8680','#A9A9A9','#C0C0C0']
ratio = [40.96,19.86,11.33,5.53,4.60,2.22, 15.5]
explode = [0.05, 0.05, 0.05, 0.05, 0.05, 0.05]
labels = ['캐릭터','요소','연출','연출(자극성)','요소(K-Drama)','소재','기타']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 2}

plt.pie(ratio,autopct='', startangle=260, 
        counterclock=False, colors=colors, wedgeprops=wedgeprops, 
        shadow = True)
plt.show()
