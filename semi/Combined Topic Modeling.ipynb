# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/home/lab08/0323.csv')

# %%
review_data = data['댓글']

# %%
from contextualized_topic_models.models.ctm import CombinedTM
from contextualized_topic_models.utils.data_preparation import TopicModelDataPreparation, bert_embeddings_from_list
from contextualized_topic_models.utils.preprocessing import WhiteSpacePreprocessing
from sklearn.feature_extraction.text import CountVectorizer
from konlpy.tag import Mecab
from tqdm import tqdm

# %%
documents = [review.strip() for review in review_data]

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
train_bow_embeddings = vectorizer.fit_transform(documents)

# %%
print(train_bow_embeddings.shape)
# Out:
# (60, 413)

# %%
vocab = vectorizer.get_feature_names()
id2token = {k : v for k, v in zip(range(0, len(vocab)), vocab)}

# %%
len(vocab)
# Out:
# 413

# %%
train_contextualized_embeddings = bert_embeddings_from_list(documents, "sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
qt = TopicModelDataPreparation()

training_dataset = qt.load(train_contextualized_embeddings, train_bow_embeddings, id2token)

# %%
ctm = CombinedTM(bow_size=len(vocab), contextual_size=768, n_components=50, num_epochs=20)
ctm.fit(training_dataset)
# Out:
# 0it [00:00, ?it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# ...

# %%
ctm.get_topics(3)
# Out:
# defaultdict(list,
#             {0: ['연기', '그걸', '아서'],
#              1: ['영상', '대박', '소개'],
#              2: ['단연', '이미', '캐릭'],
#              3: ['선택', '만렙', '골랐'],
#              4: ['경박', '버린', '인지'],
#              5: ['선화', '보장', '재밌'],
#              6: ['그냥', '여긴', '지무'],
#              7: ['한지', '이건', '대단'],
#              8: ['막장', '재밌', '채널'],
#              9: ['과거', '찰떡', '진짜'],
#              10: ['시작', '흔한', '완전'],
#              11: ['의사', '때우', '리뷰'],
#              12: ['소화', '나올', '모여'],
#              13: ['터진다', '된다', '생각'],
#              14: ['어요', '려고', '마신'],
#              15: ['인데', '졸라', 'jshbkzwltnm'],
#              16: ['입니다', '디기', '시작'],
#              17: ['면서', '이랑', '지구'],
#              18: ['언니', '올라가', '여긴'],
#              19: ['스러워서', '소화', '냨ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#              20: ['공부', '든다는', '주식'],
#              21: ['한선화', '무거운', '41'],
#              22: ['등장', '진짜', '예뻐'],
#              23: ['파손', '너무', '네요'],
# ...
